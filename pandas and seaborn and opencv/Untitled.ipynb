# %%
url = "https://www.tech-faq.com/wp-content/uploads/2009/02/rgb.jpg"

# %%
import urllib.request

# %%
urllib.request.urlretrieve(url , "modiji.jpg")
# Out:
# ('modiji.jpg', <http.client.HTTPMessage at 0x20a49807748>)

# %%
from PIL import Image

# %%
frame = Image.open("modiji.jpg")

# %%
frame
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x215 at 0x20A498D3AC8>

# %%
import numpy as np

# %%
data = np.array(frame)

# %%
data.shape
# Out:
# (215, 300, 3)

# %%
# rgb color format of the image

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(data)

# %%
work = data.copy()

# %%
work1 = data.copy()

# %%
# plt.imshow(work[ 40:320 , 20:580 , :])

# %%
work1[: , : , 0 ] = 0

# %%
plt.imshow(work1)

# %%
work[: , : , 0:2] = 0

# %%
plt.imshow(work)
